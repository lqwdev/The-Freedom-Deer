# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ### Read data

# %%
raw = pd.read_csv('cp5_data_with_sa_score.csv', lineterminator='\n')
# raw.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
raw.head()
# Out:
#       crid                        category  \
# 0  1059251                    Use Of Force
# 1  1059269  Operation/Personnel Violations
# 2  1059269  Operation/Personnel Violations
# 3  1059269  Operation/Personnel Violations
# 4  1059214  Operation/Personnel Violations
#
#                            allegation_name  allegation_category_id  \
# 0       Excessive Force / On Duty - Injury                      98
# 1  Inadequate / Failure To Provide Service                     204
# 2  Inadequate / Failure To Provide Service                     204
# 3  Inadequate / Failure To Provide Service                     204
# 4  Inadequate / Failure To Provide Service                     204
#
#     officer_race subject_race  \
# 0          White        Black
# 1          White        Black
# 2          White        Black
# 3          White        Black
# 4  Asian/Pacific        Black
#
#                                              cr_text  \
# 0  Initial / Intake Allegation 1: The reporting p...
# 1  Initial / Intake Allegation 1: Battery, allege...
# 2  Initial / Intake Allegation 1: Battery, allege...
# 3  Initial / Intake Allegation 1: Battery, allege...
# 4  Initial / Intake Allegation 1: when he called ...
#
#                                         cleaned_text  token_len  score
# 0  1: The reporting party alleges that he went to...         93  -5.85
# 1  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 2  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 3  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 4  1: when he called regarding a noise\r disturba...         35  -7.09

# %% [markdown]
# ### Run linear regression on category, officer race, and subject race

# %%
# Encode categorical variables
df = raw.copy(deep=True)
df.loc[df['allegation_category_id']==98,'allegation_category_id'] = 1
df.loc[df['allegation_category_id']==204,'allegation_category_id'] = 0
df.loc[df['officer_race']!='White','officer_race'] = 'Other'
df.loc[df['subject_race']!='Black','subject_race'] = 'Other'
df.head()
# Out:
#       crid                        category  \
# 0  1059251                    Use Of Force
# 1  1059269  Operation/Personnel Violations
# 2  1059269  Operation/Personnel Violations
# 3  1059269  Operation/Personnel Violations
# 4  1059214  Operation/Personnel Violations
#
#                            allegation_name  allegation_category_id  \
# 0       Excessive Force / On Duty - Injury                       1
# 1  Inadequate / Failure To Provide Service                       0
# 2  Inadequate / Failure To Provide Service                       0
# 3  Inadequate / Failure To Provide Service                       0
# 4  Inadequate / Failure To Provide Service                       0
#
#   officer_race subject_race  \
# 0        White        Black
# 1        White        Black
# 2        White        Black
# 3        White        Black
# 4        Other        Black
#
#                                              cr_text  \
# 0  Initial / Intake Allegation 1: The reporting p...
# 1  Initial / Intake Allegation 1: Battery, allege...
# 2  Initial / Intake Allegation 1: Battery, allege...
# 3  Initial / Intake Allegation 1: Battery, allege...
# 4  Initial / Intake Allegation 1: when he called ...
#
#                                         cleaned_text  token_len  score
# 0  1: The reporting party alleges that he went to...         93  -5.85
# 1  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 2  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 3  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 4  1: when he called regarding a noise\r disturba...         35  -7.09

# %%
# One hot coding
df_reg = pd.concat((
    df[['allegation_category_id', 'score']],
    pd.get_dummies(df['officer_race'], drop_first=True), 
    pd.get_dummies(df['subject_race'], drop_first=True)), axis=1)
df_reg.head()
# Out:
#    allegation_category_id  score  White  Other
# 0                       1  -5.85      1      0
# 1                       0  -5.75      1      0
# 2                       0  -5.75      1      0
# 3                       0  -5.75      1      0
# 4                       0  -7.09      0      0

# %%
Y = df_reg['allegation_category_id']
X = df_reg.loc[:, df_reg.columns != 'allegation_category_id']
X = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     allegation_category_id   R-squared:                       0.009
# Model:                                OLS   Adj. R-squared:                  0.008
# Method:                     Least Squares   F-statistic:                     5.732
# Date:                    Wed, 01 Dec 2021   Prob (F-statistic):           0.000667
# Time:                            02:26:10   Log-Likelihood:                -625.71
# No. Observations:                    1874   AIC:                             1259.
# Df Residuals:                        1870   BIC:                             1282.
# Df Model:                               3
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1836      0.041      4.465      0.000       0.103       0.264
# score          0.0026      0.006      0.434      0.664      -0.009       0.014
# White         -0.0588      0.016     -3.722      0.000      -0.090      -0.028
# Other         -0.0226      0.018     -1.289      0.198      -0.057       0.012
# ==============================================================================
# Omnibus:                      721.075   Durbin-Watson:                   0.446
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1956.276
# Skew:                           2.132   Prob(JB):                         0.00
# Kurtosis:                       5.622   Cond. No.                         36.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/TianchangLi/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
# Method 2 for one hot coding
# df_reg2 = df.copy(deep=True)
# df_reg2['officer_race'] = df_reg2['officer_race'].astype('category').cat.codes
# df_reg2['subject_race'] = df_reg2['subject_race'].astype('category').cat.codes
# f = 'allegation_category_id~C(officer_race)+C(subject_race)+score'
# model_cat = smf.ols(formula=f, data=df_reg2).fit()
# model_cat.summary()

# %% [markdown]
# ### Run linear regression on category, and cross-race

# %%
raw.head()
# Out:
#       crid                        category  \
# 0  1059251                    Use Of Force
# 1  1059269  Operation/Personnel Violations
# 2  1059269  Operation/Personnel Violations
# 3  1059269  Operation/Personnel Violations
# 4  1059214  Operation/Personnel Violations
#
#                            allegation_name  allegation_category_id  \
# 0       Excessive Force / On Duty - Injury                      98
# 1  Inadequate / Failure To Provide Service                     204
# 2  Inadequate / Failure To Provide Service                     204
# 3  Inadequate / Failure To Provide Service                     204
# 4  Inadequate / Failure To Provide Service                     204
#
#     officer_race subject_race  \
# 0          White        Black
# 1          White        Black
# 2          White        Black
# 3          White        Black
# 4  Asian/Pacific        Black
#
#                                              cr_text  \
# 0  Initial / Intake Allegation 1: The reporting p...
# 1  Initial / Intake Allegation 1: Battery, allege...
# 2  Initial / Intake Allegation 1: Battery, allege...
# 3  Initial / Intake Allegation 1: Battery, allege...
# 4  Initial / Intake Allegation 1: when he called ...
#
#                                         cleaned_text  token_len  score
# 0  1: The reporting party alleges that he went to...         93  -5.85
# 1  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 2  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 3  1: Battery, alleges that the\r uniformed offic...         32  -5.75
# 4  1: when he called regarding a noise\r disturba...         35  -7.09

# %%
# Encode categorical variables
df2 = raw.copy(deep=True)
df2.loc[df2['allegation_category_id']==98,'allegation_category_id'] = 1
df2.loc[df2['allegation_category_id']==204,'allegation_category_id'] = 0
df2['cross_race'] = df2['officer_race'] == df2['subject_race']
df2.loc['cross_race'] = df2['cross_race'].astype('int')
df2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
df2.tail()
# Out:
#            crid      category                     allegation_name  \
# 1869  1049715.0  Use Of Force  Excessive Force / On Duty - Injury
# 1870  1049715.0  Use Of Force  Excessive Force / On Duty - Injury
# 1871  1049715.0  Use Of Force  Excessive Force / On Duty - Injury
# 1872  1049715.0  Use Of Force  Excessive Force / On Duty - Injury
# 1873  1049715.0  Use Of Force  Excessive Force / On Duty - Injury
#
#       allegation_category_id   officer_race subject_race  \
# 1869                     1.0  Asian/Pacific        Black
# 1870                     1.0  Asian/Pacific        Black
# 1871                     1.0  Asian/Pacific        Black
# 1872                     1.0  Asian/Pacific        Black
# 1873                     1.0  Asian/Pacific        Black
#
#                                                 cr_text  \
# 1869  Initial / Intake Allegation 1: The reporting p...
# 1870  Initial / Intake Allegation 1: The reporting p...
# 1871  Initial / Intake Allegation 1: The reporting p...
# 1872  Initial / Intake Allegation 1: The reporting p...
# 1873  Initial / Intake Allegation 1: The reporting p...
#
#                                            cleaned_text  token_len  score  \
# 1869  1: The reporting party/victim alleged that the...       83.0  -7.23
# 1870  1: The reporting party/victim alleged that the...       83.0  -7.23
# 1871  1: The reporting party/victim alleged that the...       83.0  -7.23
# 1872  1: The reporting party/victim alleged that the...       83.0  -7.23
# 1873  1: The reporting party/victim alleged that the...       83.0  -7.23
#
#       cross_race
# 1869         0.0
# 1870         0.0
# 1871         0.0
# 1872         0.0
# 1873         0.0

# %%
df2_reg = df2[['allegation_category_id','score','cross_race']].copy(deep=True)
Y = df2_reg['allegation_category_id']
X = df2_reg.loc[:, df2_reg.columns != 'allegation_category_id']
X = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     allegation_category_id   R-squared:                       0.009
# Model:                                OLS   Adj. R-squared:                  0.008
# Method:                     Least Squares   F-statistic:                     8.502
# Date:                    Wed, 01 Dec 2021   Prob (F-statistic):           0.000211
# Time:                            02:26:10   Log-Likelihood:                -625.81
# No. Observations:                    1874   AIC:                             1258.
# Df Residuals:                        1871   BIC:                             1274.
# Df Model:                               2
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1687      0.041      4.165      0.000       0.089       0.248
# score          0.0017      0.006      0.281      0.779      -0.010       0.013
# cross_race    -0.0663      0.016     -4.105      0.000      -0.098      -0.035
# ==============================================================================
# Omnibus:                      721.347   Durbin-Watson:                   0.450
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1957.651
# Skew:                           2.133   Prob(JB):                         0.00
# Kurtosis:                       5.623   Cond. No.                         36.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/TianchangLi/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
