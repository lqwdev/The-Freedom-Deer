# %%
import sqlite3
import cleaning
import database
import numpy as np
import pandas as pd
import integration

# %%
results = integration.integrate()

# %%
results
# Out:
#            id           crid    event_id  beat block direction  \
# 0     1165515           NULL       10873   111   2XX         N
# 1     2192334           NULL        3180  2533  16XX         N
# 2     5909387           NULL        9201  1231  17XX         W
# 3     5776976           NULL  2009603012   411  82XX         S
# 4     5914654           NULL  2012109746   712  56XX         S
# ...       ...            ...         ...   ...   ...       ...
# 5981   105093           None  1726809310  1421  16XX     North
# 5982   105094           None  1726809310  1421  16XX     North
# 5983   105105           None  1726912358  1033  23XX     South
# 5984   105328           None  1728110679  1924  33XX     North
# 5985  3795583  2019-000-4253  1929309205  1911  47XX         N
#
#               street                       location            trr_datetime  \
# 0         Wabash Ave                       Sidewalk  2019-04-17 04:59:00 PM
# ...
