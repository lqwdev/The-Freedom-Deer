# %%
import sqlite3
import cleaning
import database
import numpy as np
import pandas as pd
import integration

# %%
trr = cleaning.process_trr()

# %%
results = integration.integrate()
# Out:
# /Users/qingweilan/Desktop/dev/ai339/ai339-project/data-cleaning/integration.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remaining['officer_id'] = 'NULL'

# %%
results
# Out:
#             id  crid    event_id  beat block direction         street  \
# 0      1165515  NULL       10873   111   2XX         N     Wabash Ave
# 1      2192334  NULL        3180  2533  16XX         N   Leclaire Ave
# 2      5909387  NULL        9201  1231  17XX         W      Taylor St
# 3      5776976  NULL  2009603012   411  82XX         S   Woodlawn Ave
# 4      5914654  NULL  2012109746   712  56XX         S      Morgan St
# ...        ...   ...         ...   ...   ...       ...            ...
# 17129   761110  None        7558  1634  50XX         W    Warwick Ave
# 17157   833879  None        1434  2515  55XX         W      Grand Ave
# 17179   962145  None        8014   822  53XX         S   St Louis Ave
# 17219  1576357  None       11892  2515  55XX         W      Grand Ave
# 17388  5004859  None       14924  1414  25XX         N  Milwaukee Ave
#
#                         location            trr_datetime indoor_or_outdoor  \
# ...
